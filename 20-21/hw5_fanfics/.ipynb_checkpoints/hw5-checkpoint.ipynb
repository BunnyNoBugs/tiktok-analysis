# %%
import pandas as pd
import requests

# %%
features_columns = [
       'Views', 'Readers', 'Likes', 
       'Collections', 'Comments',
]
data = data.dropna(subset=features_columns)

# %%
data.head()
# Out:
#        ID                                              Title    Views  \
# 0  139006     The Secret Diary of Fleur Delacour, aged 16 34   8110.0
# 1  137435  Рабочие будни Уолдена МакНейра, ликвидатора оп...   4331.0
# 2    2306                                    Яблоко Гесперид  77454.0
# 3  103183                         Однажды в другой вселенной   7595.0
# 4   98951                                    Мыс альбатросов  53937.0
#
#    Readers  Likes  Collections  Comments  \
# 0    307.0    0.0         18.0      12.0
# 1    509.0    2.0         38.0     157.0
# 2    418.0    5.0         32.0      66.0
# 3     54.0    0.0         16.0      15.0
# 4    695.0    5.0         41.0     867.0
#
#                                              Authors  \
# 0  [{'id': 553518, 'name': 'Woxers'}, {'id': 5812...
# 1                 [{'id': 235701, 'name': 'Alteya'}]
# 2  [{'id': 42332, 'name': 'PinkEos'}, {'id': 4180...
# 3           [{'id': 113285, 'name': 'Scarlett2508'}]
# ...

# %%
class DFWrapper:
    def __init__(self, dataframe, t_cl):
        self.dataframe = dataframe.dropna(subset=features_columns)
        #self.dataframe = dataframa.dropna()
        self.f_cl = t_cl

# %%
df = DFWrapper(data, 'Genre')

# %%
df.dataframe
# Out:
#            ID                                              Title    Views  \
# 0      139006     The Secret Diary of Fleur Delacour, aged 16 34   8110.0
# 1      137435  Рабочие будни Уолдена МакНейра, ликвидатора оп...   4331.0
# 2        2306                                    Яблоко Гесперид  77454.0
# 3      103183                         Однажды в другой вселенной   7595.0
# 4       98951                                    Мыс альбатросов  53937.0
# ...       ...                                                ...      ...
# 19253  107091                                   I'll take it all   7228.0
# 19254  125789                             Самый желанный подарок  10849.0
# 19255   40120                                    Деревня Лэпитте   6997.0
# 19256   64807                                    Забытый дневник   4126.0
# 19257  105257                               Гонки на гиппогрифах   7920.0
#
#        Readers  Likes  Collections  Comments  \
# ...
